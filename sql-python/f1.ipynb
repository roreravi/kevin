# %%
import pandas as pd
from sqlalchemy import create_engine
import os # Para trabajar con archivos del sistema

# %%
db_name = 'f1_database.sqlite' #CREAMOS LA BASE DE DATOS
url = 'sqlite:///{db_name}'
engine = create_engine(f'sqlite:///{db_name}')

# %%
constructor_results = pd.read_csv('/home/ravi/Documents/Kevin/kevin/sql-python/dataset_f1/constructor_results.csv')

# %%
#Aqui falta inspeccionar la tabla para ver que columnas tiene

# %%
constructor_results.to_sql('constructor_results', con=engine, index=False, if_exists='replace')
# Out:
# 12625

# %%
constructor_results.columns()

# %%
constructor_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12625 entries, 0 to 12624
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   constructorResultsId  12625 non-null  int64
#  1   raceId                12625 non-null  int64
#  2   constructorId         12625 non-null  int64
#  3   points                12625 non-null  float64
#  4   status                12625 non-null  object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 493.3+ KB

# %%
df_circuits = pd.read_csv('/home/ravi/Documents/Kevin/sql-python/dataset_f1/circuits.csv')

# %%
df_circuits.columns

# %%
df_circuits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   circuitId   77 non-null     int64
#  1   circuitRef  77 non-null     object
#  2   name        77 non-null     object
#  3   location    77 non-null     object
#  4   country     77 non-null     object
#  5   lat         77 non-null     float64
#  6   lng         77 non-null     float64
#  7   alt         77 non-null     int64
#  8   url         77 non-null     object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 5.5+ KB

# %%
#Ejercicio: Analizar todos los csv

# %%
df_circuits.to_sql('circuits', con=engine, index=False, if_exists='replace')
# Out:
# 77

# %%
df_circuits
# Out:
#     circuitId   circuitRef                                  name  \
# 0           1  albert_park        Albert Park Grand Prix Circuit
# 1           2       sepang          Sepang International Circuit
# 2           3      bahrain         Bahrain International Circuit
# 3           4    catalunya        Circuit de Barcelona-Catalunya
# 4           5     istanbul                         Istanbul Park
# ..        ...          ...                                   ...
# 72         75     portimao    Autódromo Internacional do Algarve
# 73         76      mugello  Autodromo Internazionale del Mugello
# 74         77       jeddah               Jeddah Corniche Circuit
# 75         78       losail          Losail International Circuit
# 76         79        miami         Miami International Autodrome
#
#         location       country       lat        lng  alt  \
# 0      Melbourne     Australia -37.84970  144.96800   10
# 1   Kuala Lumpur      Malaysia   2.76083  101.73800   18
# ...

# %%
constructors_standings = pd.read_csv('/Users/test/Documents/curso analista datos/kevin/sql-python/dataset_f1/constructor_standings.csv')

# %%
constructors_standings.columns
# Out:
# Index(['constructorStandingsId', 'raceId', 'constructorId', 'points',
#        'position', 'positionText', 'wins'],
#       dtype='object')

# %%
constructors_standings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13391 entries, 0 to 13390
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   constructorStandingsId  13391 non-null  int64
#  1   raceId                  13391 non-null  int64
#  2   constructorId           13391 non-null  int64
#  3   points                  13391 non-null  float64
#  4   position                13391 non-null  int64
#  5   positionText            13391 non-null  object
#  6   wins                    13391 non-null  int64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 732.4+ KB

# %%
constructors_standings.to_sql('constructors_standings', con=engine, index=False, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 constructors_standings.to_sql('constructors_standings', con=engine, index=False, if_exists='replace')
#
# NameError: name 'engine' is not defined

# %%
constructors = pd.read_csv('/Users/test/Documents/curso analista datos/kevin/sql-python/dataset_f1/constructors.csv')

# %%
constructors.columns
# Out:
# Index(['constructorId', 'constructorRef', 'name', 'nationality', 'url'], dtype='object')

# %%
constructors.head()
# Out:
#    constructorId constructorRef        name nationality  \
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian
#
#                                                  url
# 0               http://en.wikipedia.org/wiki/McLaren
# 1            http://en.wikipedia.org/wiki/BMW_Sauber
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso

# %%
constructors.info
# Out:
# <bound method DataFrame.info of      constructorId constructorRef            name nationality  \
# 0                1        mclaren         McLaren     British
# 1                2     bmw_sauber      BMW Sauber      German
# 2                3       williams        Williams     British
# 3                4        renault         Renault      French
# 4                5     toro_rosso      Toro Rosso     Italian
# ..             ...            ...             ...         ...
# 207            210           haas    Haas F1 Team    American
# 208            211   racing_point    Racing Point     British
# 209            213     alphatauri      AlphaTauri     Italian
# 210            214         alpine  Alpine F1 Team      French
# 211            215             rb      RB F1 Team     Italian
#
#                                                    url
# 0                 http://en.wikipedia.org/wiki/McLaren
# 1              http://en.wikipedia.org/wiki/BMW_Sauber
# ...

# %%
constructors.to_sql('constructors', con=engine, index=False, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 constructors.to_sql('constructors', con=engine, index=False, if_exists='replace')
#
# NameError: name 'engine' is not defined

# %%
driver_standings = pd.read_csv('/Users/test/Documents/curso analista datos/kevin/sql-python/dataset_f1/driver_standings.csv')

# %%
driver_standings.columns
# Out:
# Index(['driverStandingsId', 'raceId', 'driverId', 'points', 'position',
#        'positionText', 'wins'],
#       dtype='object')

# %%
driver_standings.info
# Out:
# <bound method DataFrame.info of        driverStandingsId  raceId  driverId  points  position positionText  \
# 0                      1      18         1    10.0         1            1
# 1                      2      18         2     8.0         2            2
# 2                      3      18         3     6.0         3            3
# 3                      4      18         4     5.0         4            4
# 4                      5      18         5     4.0         5            5
# ...                  ...     ...       ...     ...       ...          ...
# 34858              73266    1144       858     0.0        23           23
# 34859              73267    1144       860     7.0        18           18
# 34860              73268    1144       861     5.0        19           19
# 34861              73269    1144       859     4.0        21           21
# 34862              73270    1144       862     0.0        24           24
#
#        wins
# 0         1
# 1         0
# ...

# %%
drivers = pd.read_csv('/Users/test/Documents/curso analista datos/kevin/sql-python/dataset_f1/drivers.csv')

# %%
drivers.columns
# Out:
# Index(['driverId', 'driverRef', 'number', 'code', 'forename', 'surname', 'dob',
#        'nationality', 'url'],
#       dtype='object')

# %%
drivers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 861 entries, 0 to 860
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   driverId     861 non-null    int64
#  1   driverRef    861 non-null    object
#  2   number       861 non-null    object
#  3   code         861 non-null    object
#  4   forename     861 non-null    object
#  5   surname      861 non-null    object
#  6   dob          861 non-null    object
#  7   nationality  861 non-null    object
#  8   url          861 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 60.7+ KB

# %%
drivers.head()
# Out:
#    driverId   driverRef number code  forename     surname         dob  \
# 0         1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
# Todo lo que puedas hacer con sql, hazlo con sql 
#Cuando la consulta es simple
df = pd.read_sql_query('SELECT * FROM circuits', engine)

# Cuando la consulta es más compleja, podemos usar una cadena de texto 
#Escribimos la consulta
query = '''
            SELECT circuitId,	circuitRef,	name 
            FROM circuits
            WHERE circuitId = 1;
        '''
# Ejecutamos la consulta y guardamos el resultado en un DataFrame
df_circuits = pd.read_sql_query(query, engine) 

# Cuando necesitemos hacer cambios a la base de datos 
with engine.connect() as connection:
    connection.execute('delete from circuits where circuitId = 1;')

# %%
df_circuits
# Out:
#     circuitId   circuitRef                                  name
# 0           1  albert_park        Albert Park Grand Prix Circuit
# 1           2       sepang          Sepang International Circuit
# 2           3      bahrain         Bahrain International Circuit
# 3           4    catalunya        Circuit de Barcelona-Catalunya
# 4           5     istanbul                         Istanbul Park
# ..        ...          ...                                   ...
# 72         75     portimao    Autódromo Internacional do Algarve
# 73         76      mugello  Autodromo Internazionale del Mugello
# 74         77       jeddah               Jeddah Corniche Circuit
# 75         78       losail          Losail International Circuit
# 76         79        miami         Miami International Autodrome
#
# [77 rows x 3 columns]

# %% [markdown]
# preguntar a ravi que me explique de nuevo, porque sino lo engancho de entrada despues no voy a entender nada, como pasar todas las carpetas a sql paso a paso

# %%
# Creamos la base de datos y cargamos los archivos CSV en tablas
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

#Created on Thu Oct 19 11:00:00 2023

import pandas as pd
from sqlalchemy import create_engine, text

# Define la ruta donde tienes los archivos CSV
data_path = './dataset_f1/'  # Asegúrate de que los archivos CSV estén en este directorio o ajusta la ruta

# Define el nombre de la base de datos SQLite
db_name = 'formula1.sqlite'
engine = create_engine(f'sqlite:///{db_name}')

# Lista de archivos CSV y sus correspondientes nombres de tabla
csv_files = {
    'circuits.csv': 'circuits',
    'constructor_results.csv': 'constructor_results',
    'constructor_standings.csv': 'constructor_standings',
    'constructors.csv': 'constructors',
    'driver_standings.csv': 'driver_standings',
    'drivers.csv': 'drivers',
    'lap_times.csv': 'lap_times',
    'pit_stops.csv': 'pit_stops',
    'qualifying.csv': 'qualifying',
    'races.csv': 'races',
    'results.csv': 'results',
    'seasons.csv': 'seasons',
    'sprint_results.csv': 'sprint_results',
    'status.csv': 'status'
}

try:
    # Itera sobre los archivos CSV y los carga en la base de datos
    for file_name, table_name in csv_files.items():
        file_path = f'{data_path}{file_name}'
        try:
            df = pd.read_csv(file_path)
            df.to_sql(table_name, engine, if_exists='replace', index=False)
            print(f'Tabla "{table_name}" cargada exitosamente desde "{file_name}".')
        except FileNotFoundError:
            print(f'Error: El archivo "{file_path}" no fue encontrado.')
        except Exception as e:
            print(f'Error al cargar la tabla "{table_name}" desde "{file_name}": {e}')

    print('\n¡Todas las tablas han sido procesadas!')

except Exception as e:
    print(f'Ocurrió un error general: {e}')
finally:
    # Cierra la conexión a la base de datos
    engine.dispose()
    print('\nConexión a la base de datos cerrada.')
# Out:
# Tabla "circuits" cargada exitosamente desde "circuits.csv".
# Tabla "constructor_results" cargada exitosamente desde "constructor_results.csv".
# Tabla "constructor_standings" cargada exitosamente desde "constructor_standings.csv".
# Tabla "constructors" cargada exitosamente desde "constructors.csv".
# Tabla "driver_standings" cargada exitosamente desde "driver_standings.csv".
# Tabla "drivers" cargada exitosamente desde "drivers.csv".
# Tabla "lap_times" cargada exitosamente desde "lap_times.csv".
# Tabla "pit_stops" cargada exitosamente desde "pit_stops.csv".
# Tabla "qualifying" cargada exitosamente desde "qualifying.csv".
# Tabla "races" cargada exitosamente desde "races.csv".
# Tabla "results" cargada exitosamente desde "results.csv".
# Tabla "seasons" cargada exitosamente desde "seasons.csv".
# Tabla "sprint_results" cargada exitosamente desde "sprint_results.csv".
# Tabla "status" cargada exitosamente desde "status.csv".
#
# ¡Todas las tablas han sido procesadas!
#
# ...

# %%
# Investigar como tener un directorio de codigo para reciclar

# %%
from sqlalchemy import create_engine, inspect

# Define el nombre de la base de datos SQLite
db_name = 'formula1.sqlite'
engine = create_engine(f'sqlite:///{db_name}')

# Crea un objeto inspector para examinar la base de datos
inspector = inspect(engine)

# Obtiene la lista de todos los nombres de las tablas
table_names = inspector.get_table_names()

print('Esquema de la base de datos:')
for table_name in table_names:
    print(f'\nTabla: {table_name}')
    columns = inspector.get_columns(table_name)
    print('  Columnas:')
    for column in columns:
        print(f'    - {column["name"]} ({column["type"]}), Primary Key: {column["primary_key"]}, Nullable: {column["nullable"]}')
    foreign_keys = inspector.get_foreign_keys(table_name)
    if foreign_keys:
        print('  Claves Foráneas:')
        for fk in foreign_keys:
            referenced_table = fk["referred_table"]
            local_columns = fk["constrained_columns"]
            referenced_columns = fk["referred_columns"]
            print(f'    - {local_columns} referencia a {referenced_table}.{referenced_columns}')

# Cierra la conexión a la base de datos
engine.dispose()
# Out:
# Esquema de la base de datos:
#
# Tabla: circuits
#   Columnas:
#     - circuitId (BIGINT), Primary Key: 0, Nullable: True
#     - circuitRef (TEXT), Primary Key: 0, Nullable: True
#     - name (TEXT), Primary Key: 0, Nullable: True
#     - location (TEXT), Primary Key: 0, Nullable: True
#     - country (TEXT), Primary Key: 0, Nullable: True
#     - lat (FLOAT), Primary Key: 0, Nullable: True
#     - lng (FLOAT), Primary Key: 0, Nullable: True
#     - alt (BIGINT), Primary Key: 0, Nullable: True
#     - url (TEXT), Primary Key: 0, Nullable: True
#
# Tabla: constructor_results
#   Columnas:
#     - constructorResultsId (BIGINT), Primary Key: 0, Nullable: True
#     - raceId (BIGINT), Primary Key: 0, Nullable: True
#     - constructorId (BIGINT), Primary Key: 0, Nullable: True
#     - points (FLOAT), Primary Key: 0, Nullable: True
#     - status (TEXT), Primary Key: 0, Nullable: True
#
# Tabla: constructor_standings
#   Columnas:
# ...

# %%
# Dibujar el esquema de la base de datos en draw.io
# Puedes usar la herramienta draw.io para crear un diagrama visual del esquema de la base de datos.

# %%
#Adelanto de la proxima clase:

# Ejemplo de consulta SQL para obtener los mejores pilotos por temporada
query = '''
    SELECT d.driverId, d.forename, d.surname, ds.season, ds.points
    FROM driver_standings ds
    JOIN drivers d ON ds.driverId = d.driverId
    WHERE ds.points = (
        SELECT MAX(points)
        FROM driver_standings
        WHERE season = ds.season
    )
    ORDER BY ds.season;
'''
# Ejecuta la consulta y muestra los resultados
